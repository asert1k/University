# %% [markdown]
# <a href="https://colab.research.google.com/github/asert1k/University/blob/main/Tasks/First_programm_lyoha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello, world")
print("hello, lyoha")
# Out:
# hello, world
# hello, lyoha
